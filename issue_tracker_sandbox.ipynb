# %% [markdown]
# ```sql
#
# CREATE TABLE issue (
#
#     issue_id INTEGER PRIMARY KEY AUTOINCREMENT,
#     name TEXT,
#     description TEXT,
#     due_date DATE,
#     priority INTEGER
# );
#
# ```
#
# ```sql
# INSERT INTO issue (name, description, due_date, priority) VALUES
# ('Einkaufen','Kaufe Milch und Eier', '2026-02-23', 1 );
#
#
# ```

# %%
connection = connect("issue_tracker.db")

# %%
from sqlite3 import connect

# %%
sql = """
CREATE TABLE issue (

    issue_id INTEGER PRIMARY KEY AUTOINCREMENT, 
    name TEXT, 
    description TEXT, 
    due_date DATE, 
    priority INTEGER
);

"""
cursor = connection.execute(sql)
connection.commit()

# %%
sql = """
CREATE TABLE issue (

INSERT INTO issue (name, description, due_date, priority) VALUES 
('Einkaufen','Kaufe Milch und Eier', '2026-02-23', 1 );
    
);

"""
cursor = connection.execute(sql)
connection.commit()

# %%
cursor = connection.execute("SELECT * from issue;")
cursor.fetchall()
